# %% [markdown]
# # How long does it take you to draw a map?

# %% [markdown]
# <img src="images/geopython-2019.png">
#
# # Geomapping with Pyecharts(Echarts.js)
# ## Chenfu Wang /ˈtʃnfu ˈwa:ŋ/

# %% [markdown]
# # About Me
#
# ## Python consultant, London, knows a bit of javascript
#
# ## pyexcel and pyecharts
#
# ## brython-pack, moban

# %% [markdown]
# # User Stories

# %% [markdown]
# # An employee with a University degree in Material Science in non-IT company, wanted to plot our their suppliers on the map.
#
#
# # A student admission coordinator in a college would like to map their new students by their home city.
#
# # A county planner would like to plot some geo locations on their county.

# %% [markdown]
# # What is Pyecharts?
#
# ## Python interface to Echarts.js visualisation library.
#
# ## Written by Chen, Jiandong,  in 2017,  a Chinese undergraduate at year 2.
#
# <img src="images/charts.png" style="height:400px">

# %% [markdown]
# # What is Echarts.js?
#
# ## Released in 2013, attracting 34k starts. Apache licensed. Popular in China
#
# | library          | Extended Charts   |  Custom Interaction   | Canvas      |
# |------------------|-------------------|-----------------------|-------------|
# |   Highcharts.js  | No                | No                    | No          |
# |   Charts.js      | No                | No                    | Yes         |
# |   C3.js          | No                | No                    | No          |
# |   Echarts.js     | Yes               | Yes                   | Yes         |

# %% [markdown]
# # What's the place for pyecharts?
#
# | Library       | Interactivity   | Image export(svg, eps, pdf, html)  | Communities      |
# |---------------|-----------------|------------------------------------|------------------|
# |   Matplotlib  | No              | Yes                                | Academia         |
# |   Plotly      | Yes             | No                                 | Data Scientist   |
# |   Bokeh       | Yes             | Yes                                | Data Scientist   |
# |   pyecharts   | Yes             | Yes                                | Programmers      |

# %% [markdown]
# # Why
#
# ## Simple - Given a geojson, it displays it. No projection and no rotation are needed
# ## Interactive - By default, reader involvement is assumed
# ## Digital native - Quick to share on the web.

# %% [markdown]
# <img src="images/statistics.png" width=800>

# %% [markdown]
# ![china-cities.png](attachment:china-cities.png)

# %% [markdown]
# # What's covered in the talk
#
# ##     1.  the techniques that I have used in creating the geomap assets
# ##     2. the integration of echarts.js with python, especially with jupyter notebook
# ##     3. the way to create your own map assets, https://bit.ly/2FrDxHE

# %% [markdown]
# # First of all, Where are readily available geo shapes. - Part 1 (1/3)
#
# ## 1. Open data initialitives, Notably a lot of governments have made plenty of geoshapes public
# ## 2. Natural Earth Data
# ## 3. Open Street Map
# ## 4. Gaode maps (高德地图), under fair usage principle.
# ## 5. Draw it yourself

# %% [markdown]
# # Geoshape Maintenance - Part 1 (2/3)
#
# ## 1 Geo-shapes evolve.
# ### a. Name change
# ### b. New district joins
# ### c. Merger of different districts

# %% [markdown]
# ## User needs - - Part 1 (3/3)
#
# ## a. Shape without borders, Shape with borders
# ## b. Custom groupings.
# ## c. Custom projection

# %% [markdown]
# <img src="images/beijing.png">

# %% [markdown]
# <table>
#     <tr>
#         <td style="align:center"> Provincial borders</td>
#         <td> Regional borders </td>
#     </tr>
#     <tr>
#         <td><img src="images/China.png"></td>
#         <td><img src="images/China-by-seven-regions.png"></td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="images/original-world.png"></td>
#         <td><img src="images/eckert3-world.png"></td>
#     </tr>
# </table>

# %% [markdown]
# # Part 2: How to integrate a javascript library with python, especially jupyter notebook

# %% [markdown]
# # Python Interface - Part 2 - (1/3)
#
# <img src="images/pyecharts-code.png">

# %% [markdown]
# # The output of pyecharts - Part 2 - (2/3)
#
# <img src="images/render.png">

# %% [markdown]
# # Jupyter Notebook - Part 2 - (3/3)
#
# <img src="images/jupyter.png">

# %% [markdown]
# # Part 3: how to create your own map asset for pyecharts
#
# ## Pre-requistes
#
# ### Node.js, echarts-mapmaker

# %% [markdown]
# # The Forbidden City Demo
#
# ## Step 1. Draw the shape with geojson.io
#
# <img src="images/geojson-3.png">

# %% [markdown]
# # Step 2: Convert geojson to javascript
#
# ## makejs The-Forbidden-City.geojson The-Forbidden-City.js "The Forbidden City"
#
# # Step 3: Create registration json
#
# <img src="images/step-3.png">
#
# # Step 4: Host it locally
#
# <img src="images/step-4.png">

# %% [markdown]
# # Step 5: Render it
#
# <img src="images/step-5.png">

# %% [markdown]
# # Step 6: Viewing it
#
# <img src="images/the-forbidden-city-en.png">

# %% [markdown]
# # Step 7: Share it

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.datasets import register_url

register_url("https://echarts-maps.github.io/The-Forbidden-City-Demo")

g = (
       Geo()
        .add_schema(maptype="The Forbidden City")
        .set_global_opts(
            title_opts=opts.TitleOpts(title="The Forbidden City in Beijing"),
        )
)
g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'The Forbidden City':'https://echarts-maps.github.io/The-Forbidden-City-Demo/The-Forbidden-City'
#         }
#     });
# </script>
#
#     <div id="293c09ff5f6243d7be125ddccba31434" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'The Forbidden City'], function(echarts) {
#         var chart_293c09ff5f6243d7be125ddccba31434 = echarts.init(
#             document.getElementById('293c09ff5f6243d7be125ddccba31434'), 'white', {renderer: 'canvas'});
#         var option_293c09ff5f6243d7be125ddccba31434 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
# ...

# %% [markdown]
# # Final demo: United Kingdom Voting Map
#
# # https://bit.ly/2Rxl2X3
#
# <img src="images/demo-2017-electroal-results.gif" style="height:500px">

# %% [markdown]
# # Thanks
#
# # Questions?
#
# # follow me on https://github.com/chfw
