# %% [markdown]
# <img src="images/logo.png" width="300px">
# <img src="images/echarts.png" width="300px">

# %% [markdown]
# # Tranditional Bar Chart

# %%
from example.commons import Collector, Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Page
from pyecharts.commons.utils import JsCode


def bar_base() -> Bar:
    c = (
        Bar()
        .add_xaxis(["Mi", "Samsung", "Huawei", "Apple", "HTC", "VIVO", "OPPO"])
        .add_yaxis("shop A", Faker.values())
        .add_yaxis("shop B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Example handset sales", subtitle="explaning the charts"))
    )
    return c

bar_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="a4c8d6298d45494aa535cd57e4bb5b28" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_a4c8d6298d45494aa535cd57e4bb5b28 = echarts.init(
#             document.getElementById('a4c8d6298d45494aa535cd57e4bb5b28'), 'white', {renderer: 'canvas'});
#         var option_a4c8d6298d45494aa535cd57e4bb5b28 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "shop A",
#             "data": [
#                 94,
#                 146,
#                 61,
#                 30,
#                 34,
#                 93,
#                 43
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "shop B",
#             "data": [
#                 33,
#                 133,
#                 138,
#                 141,
#                 137,
#                 70,
#                 63
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "shop A",
#                 "shop B"
#             ],
#             "selected": {
#                 "shop A": true,
#                 "shop B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Mi",
#                 "Samsung",
#                 "Huawei",
#                 "Apple",
#                 "HTC",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Example handset sales",
#             "subtext": "explaning the charts"
#         }
#     ]
# };
#         chart_a4c8d6298d45494aa535cd57e4bb5b28.setOption(option_a4c8d6298d45494aa535cd57e4bb5b28);
#     });
# </script>

# %% [markdown]
# # Time Line

# %%
from example.commons import Collector, Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Map, Page, Pie, Timeline


def timeline_bar() -> Timeline:
    x = Faker.choose()
    tl = Timeline()
    for i in range(2015, 2020):
        bar = (
            Bar()
            .add_xaxis(["Mi", "Samsung", "Huawei", "Apple", "HTC", "VIVO", "OPPO"])
            .add_yaxis("shop A", Faker.values())
            .add_yaxis("shop B", Faker.values())
            .set_global_opts(title_opts=opts.TitleOpts("Sales figure in {}".format(i)))
        )
        tl.add(bar, "year {}".format(i))
    return tl

timeline_bar().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="ed8f68d5b2fc47b9a1c9c6e2093b9a19" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_ed8f68d5b2fc47b9a1c9c6e2093b9a19 = echarts.init(
#             document.getElementById('ed8f68d5b2fc47b9a1c9c6e2093b9a19'), 'white', {renderer: 'canvas'});
#         var option_ed8f68d5b2fc47b9a1c9c6e2093b9a19 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "shop A",
#                 "data": [
#                     85,
#                     28,
#                     126,
#                     71,
#                     69,
#                     64,
#                     88
#                 ],
#                 "barCategoryGap": "20%",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": "shop B",
#                 "data": [
#                     54,
#                     74,
#                     118,
#                     73,
#                     105,
#                     76,
#                     32
#                 ],
#                 "barCategoryGap": "20%",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "year 2015",
#                 "year 2016",
#                 "year 2017",
#                 "year 2018",
#                 "year 2019"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "Mi",
#                     "Samsung",
#                     "Huawei",
#                     "Apple",
#                     "HTC",
#                     "VIVO",
#                     "OPPO"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "shop A",
#                         "shop B"
#                     ],
#                     "selected": {
#                         "shop A": true,
#                         "shop B": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         147,
#                         108,
#                         83,
#                         68,
#                         45,
#                         64,
#                         84
#                     ]
#                 },
#                 {
#                     "data": [
#                         72,
#                         81,
#                         46,
#                         42,
#                         61,
#                         28,
#                         73
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "Sales figure in 2015"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             }
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "shop A",
#                         "shop B"
#                     ],
#                     "selected": {
#                         "shop A": true,
#                         "shop B": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         91,
#                         112,
#                         122,
#                         79,
#                         29,
#                         58,
#                         70
#                     ]
#                 },
#                 {
#                     "data": [
#                         60,
#                         59,
#                         54,
#                         31,
#                         110,
#                         125,
#                         128
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "Sales figure in 2016"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             }
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "shop A",
#                         "shop B"
#                     ],
#                     "selected": {
#                         "shop A": true,
#                         "shop B": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         22,
#                         79,
#                         141,
#                         131,
#                         115,
#                         129,
#                         111
#                     ]
#                 },
#                 {
#                     "data": [
#                         127,
#                         51,
#                         138,
#                         107,
#                         132,
#                         66,
#                         62
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "Sales figure in 2017"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0

# %% [markdown]
# # Heat Map on Calendar

# %%
import random

from example.commons import Faker
from pyecharts import options as opts
from pyecharts.charts import HeatMap, Page


def heatmap_base() -> HeatMap:
    value = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
    c = (
        HeatMap()
        .add_xaxis(Faker.clock)
        .add_yaxis("Someone's github contribution", Faker.week_en, value)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="HeatMap - weekly calendar"),
            visualmap_opts=opts.VisualMapOpts(),
        )
    )
    return c


heatmap_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="cdfe0bdd01dc43dcb4ba7c3fd9dbc2bd" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_cdfe0bdd01dc43dcb4ba7c3fd9dbc2bd = echarts.init(
#             document.getElementById('cdfe0bdd01dc43dcb4ba7c3fd9dbc2bd'), 'white', {renderer: 'canvas'});
#         var option_cdfe0bdd01dc43dcb4ba7c3fd9dbc2bd = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "Someone's github contribution",
#             "data": [
#                 [
#                     0,
#                     0,
#                     5
#                 ],
#                 [
#                     0,
#                     1,
#                     44
#                 ],
#                 [
#                     0,
#                     2,
#                     22
#                 ],
#                 [
#                     0,
#                     3,
#                     46
#                 ],
#                 [
#                     0,
#                     4,
#                     1
#                 ],
#                 [
#                     0,
#                     5,
#                     33
#                 ],
#                 [
#                     0,
#                     6,
#                     20
#                 ],
#                 [
#                     1,
#                     0,
#                     6
#                 ],
#                 [
#                     1,
#                     1,
#                     43
#                 ],
#                 [
#                     1,
#                     2,
#                     7
#                 ],
#                 [
#                     1,
#                     3,
#                     43
#                 ],
#                 [
#                     1,
#                     4,
#                     36
#                 ],
#                 [
#                     1,
#                     5,
#                     29
#                 ],
#                 [
#                     1,
#                     6,
#                     8
#                 ],
#                 [
#                     2,
#                     0,
#                     3
#                 ],
#                 [
#                     2,
#                     1,
#                     44
#                 ],
#                 [
#                     2,
#                     2,
#                     37
#                 ],
#                 [
#                     2,
#                     3,
#                     8
#                 ],
#                 [
#                     2,
#                     4,
#                     40
#                 ],
#                 [
#                     2,
#                     5,
#                     0
#                 ],
#                 [
#                     2,
#                     6,
#                     10
#                 ],
#                 [
#                     3,
#                     0,
#                     19
#                 ],
#                 [
#                     3,
#                     1,
#                     49
#                 ],
#                 [
#                     3,
#                     2,
#                     5
#                 ],
#                 [
#                     3,
#                     3,
#                     49
#                 ],
#                 [
#                     3,
#                     4,
#                     38
#                 ],
#                 [
#                     3,
#                     5,
#                     43
#                 ],
#                 [
#                     3,
#                     6,
#                     6
#                 ],
#                 [
#                     4,
#                     0,
#                     18
#                 ],
#                 [
#                     4,
#                     1,
#                     1
#                 ],
#                 [
#                     4,
#                     2,
#                     40
#                 ],
#                 [
#                     4,
#                     3,
#                     1
#                 ],
#                 [
#                     4,
#                     4,
#                     16
#                 ],
#                 [
#                     4,
#                     5,
#                     19
#                 ],
#                 [
#                     4,
#                     6,
#                     39
#                 ],
#                 [
#                     5,
#                     0,
#                     13
#                 ],
#                 [
#                     5,
#                     1,
#                     49
#                 ],
#                 [
#                     5,
#                     2,
#                     0
#                 ],
#                 [
#                     5,
#                     3,
#                     14
#                 ],
#                 [
#                     5,
#                     4,
#                     28
#                 ],
#                 [
#                     5,
#                     5,
#                     25
#                 ],
#                 [
#                     5,
#                     6,
#                     38
#                 ],
#                 [
#                     6,
#                     0,
#                     4
#                 ],
#                 [
#                     6,
#                     1,
#                     28
#                 ],
#                 [
#                     6,
#                     2,
#                     12
#                 ],
#                 [
#                     6,
#                     3,
#                     15
#                 ],
#                 [
#                     6,
#                     4,
#                     44
#                 ],
#                 [
#                     6,
#                     5,
#                     23
#                 ],
#                 [
#                     6,
#                     6,
#                     15
#                 ],
#                 [
#                     7,
#                     0,
#                     32
#                 ],
#                 [
#                     7,
#                     1,
#                     5
#                 ],
#                 [
#                     7,
#                     2,
#                     5
#                 ],
#                 [
#                     7,
#                     3,
#                     13
#                 ],
#                 [
#                     7,
#                     4,
#                     22
#                 ],
#                 [
#                     7,
#                     5,
#                     39
#                 ],
#                 [
#                     7,
#                     6,
#                     24
#                 ],
#                 [
#                     8,
#                     0,
#                     31
#                 ],
#                 [
#                     8,
#                     1,
#                     34
#                 ],
#                 [
#                     8,
#                     2,
#                     12
#                 ],
#                 [
#                     8,
#                     3,
#                     41
#                 ],
#                 [
#                     8,
#                     4,
#                     11
#                 ],
#                 [
#                     8,
#                     5,
#                     43
#                 ],
#                 [
#                     8,
#                     6,
#                     37
#                 ],
#                 [
#                     9,
#                     0,
#                     11
#                 ],
#                 [
#                     9,
#                     1,
#                     38

# %% [markdown]
# # Heat Map on Calendar

# %%
import random

from example.commons import Collector, Faker
from pyecharts import options as opts
from pyecharts.charts import Bar3D, Page

def bar3d_base() -> Bar3D:
    data = [(i, j, random.randint(0, 12)) for i in range(6) for j in range(24)]
    c = (
        Bar3D()
        .add(
            "",
            [[d[1], d[0], d[2]] for d in data],
            xaxis3d_opts=opts.Axis3DOpts(Faker.clock, type_="category"),
            yaxis3d_opts=opts.Axis3DOpts(Faker.week_en, type_="category"),
            zaxis3d_opts=opts.Axis3DOpts(type_="value"),
        )
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(max_=20),
            title_opts=opts.TitleOpts(title="Bar3D in week calendar"),
        )
    )
    return c


bar3d_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#     <div id="fcf38939715742028f05860ed3052a81" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-gl'], function(echarts) {
#         var chart_fcf38939715742028f05860ed3052a81 = echarts.init(
#             document.getElementById('fcf38939715742028f05860ed3052a81'), 'white', {renderer: 'canvas'});
#         var option_fcf38939715742028f05860ed3052a81 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar3D",
#             "data": [
#                 [
#                     0,
#                     0,
#                     0
#                 ],
#                 [
#                     1,
#                     0,
#                     12
#                 ],
#                 [
#                     2,
#                     0,
#                     3
#                 ],
#                 [
#                     3,
#                     0,
#                     2
#                 ],
#                 [
#                     4,
#                     0,
#                     3
#                 ],
#                 [
#                     5,
#                     0,
#                     10
#                 ],
#                 [
#                     6,
#                     0,
#                     5
#                 ],
#                 [
#                     7,
#                     0,
#                     0
#                 ],
#                 [
#                     8,
#                     0,
#                     9
#                 ],
#                 [
#                     9,
#                     0,
#                     10
#                 ],
#                 [
#                     10,
#                     0,
#                     4
#                 ],
#                 [
#                     11,
#                     0,
#                     4
#                 ],
#                 [
#                     12,
#                     0,
#                     10
#                 ],
#                 [
#                     13,
#                     0,
#                     3
#                 ],
#                 [
#                     14,
#                     0,
#                     1
#                 ],
#                 [
#                     15,
#                     0,
#                     10
#                 ],
#                 [
#                     16,
#                     0,
#                     0
#                 ],
#                 [
#                     17,
#                     0,
#                     6
#                 ],
#                 [
#                     18,
#                     0,
#                     1
#                 ],
#                 [
#                     19,
#                     0,
#                     4
#                 ],
#                 [
#                     20,
#                     0,
#                     12
#                 ],
#                 [
#                     21,
#                     0,
#                     1
#                 ],
#                 [
#                     22,
#                     0,
#                     5
#                 ],
#                 [
#                     23,
#                     0,
#                     2
#                 ],
#                 [
#                     0,
#                     1,
#                     0
#                 ],
#                 [
#                     1,
#                     1,
#                     7
#                 ],
#                 [
#                     2,
#                     1,
#                     2
#                 ],
#                 [
#                     3,
#                     1,
#                     11
#                 ],
#                 [
#                     4,
#                     1,
#                     3
#                 ],
#                 [
#                     5,
#                     1,
#                     4
#                 ],
#                 [
#                     6,
#                     1,
#                     1
#                 ],
#                 [
#                     7,
#                     1,
#                     4
#                 ],
#                 [
#                     8,
#                     1,
#                     8
#                 ],
#                 [
#                     9,
#                     1,
#                     1
#                 ],
#                 [
#                     10,
#                     1,
#                     0
#                 ],
#                 [
#                     11,
#                     1,
#                     5
#                 ],
#                 [
#                     12,
#                     1,
#                     4
#                 ],
#                 [
#                     13,
#                     1,
#                     9
#                 ],
#                 [
#                     14,
#                     1,
#                     10
#                 ],
#                 [
#                     15,
#                     1,
#                     12
#                 ],
#                 [
#                     16,
#                     1,
#                     7
#                 ],
#                 [
#                     17,
#                     1,
#                     8
#                 ],
#                 [
#                     18,
#                     1,
#                     0
#                 ],
#                 [
#                     19,
#                     1,
#                     12
#                 ],
#                 [
#                     20,
#                     1,
#                     0
#                 ],
#                 [
#                     21,
#                     1,
#                     12
#                 ],
#                 [
#                     22,
#                     1,
#                     6
#                 ],
#                 [
#                     23,
#                     1,
#                     6
#                 ],
#                 [
#                     0,
#                     2,
#                     8
#                 ],
#                 [
#                     1,
#                     2,
#                     5
#                 ],
#                 [
#                     2,
#                     2,
#                     5
#                 ],
#                 [
#                     3,
#                     2,
#                     12
#                 ],
#                 [
#                     4,
#                     2,
#                     12
#                 ],
#                 [
#                     5,
#                     2,
#                     12
#                 ],
#                 [
#                     6,
#                     2,
#                     11
#                 ],
#                 [
#                     7,
#                     2,
#                     7
#                 ],
#                 [
#                     8,
#                     2,
#                     4
#                 ],
#                 [
#                     9,
#                     2,
#                     5
#                 ],
#                 [
#                     10,
#                     2,
#                     10
#                 ],
#                 [
#                     11,
#                     2,
#                     10
#                 ],
#                 [
#                     12,
#                     2,
#                     9
#                 ],
#                 [
#                     13,
#                     2,
#                     4
#                 ],
#                 [
#                     14,
#                     2,
#                     1
#                 ],
#                 [
#                     15,
#                     2,
#                     5
#                 ],
#                 [
#                     16,
#                     2,

# %% [markdown]
# # Graph

# %%
import json
import os

from example.commons import Collector
from pyecharts import options as opts
from pyecharts.charts import Graph, Page


def graph_base() -> Graph:
    nodes = [
        {"name": "node1", "symbolSize": 10},
        {"name": "node2", "symbolSize": 20},
        {"name": "node3", "symbolSize": 30},
        {"name": "node4", "symbolSize": 40},
        {"name": "node5", "symbolSize": 50},
        {"name": "node6", "symbolSize": 40},
        {"name": "node7", "symbolSize": 30},
        {"name": "node8", "symbolSize": 20},
    ]
    links = []
    for i in nodes:
        for j in nodes:
            links.append({"source": i.get("name"), "target": j.get("name")})
    c = (
        Graph()
        .add("", nodes, links, repulsion=8000)
        .set_global_opts(title_opts=opts.TitleOpts(title="Basic Graph"))
    )
    return c

graph_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="9e51046927094fd38a0fd96cc11ab093" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_9e51046927094fd38a0fd96cc11ab093 = echarts.init(
#             document.getElementById('9e51046927094fd38a0fd96cc11ab093'), 'white', {renderer: 'canvas'});
#         var option_9e51046927094fd38a0fd96cc11ab093 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 8000,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "node1",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "node2",
#                     "symbolSize": 20
#                 },
#                 {
#                     "name": "node3",
#                     "symbolSize": 30
#                 },
#                 {
#                     "name": "node4",
#                     "symbolSize": 40
#                 },
#                 {
#                     "name": "node5",
#                     "symbolSize": 50
#                 },
#                 {
#                     "name": "node6",
#                     "symbolSize": 40
#                 },
#                 {
#                     "name": "node7",
#                     "symbolSize": 30
#                 },
#                 {
#                     "name": "node8",
#                     "symbolSize": 20
#                 }
#             ],
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "node1",
#                     "target": "node1"
#                 },
#                 {
#                     "source": "node1",
#                     "target": "node2"
#                 },
#                 {
#                     "source": "node1",
#                     "target": "node3"
#                 },
#                 {
#                     "source": "node1",
#                     "target": "node4"
#                 },
#                 {
#                     "source": "node1",
#                     "target": "node5"
#                 },
#                 {
#                     "source": "node1",
#                     "target": "node6"
#                 },
#                 {
#                     "source": "node1",
#                     "target": "node7"
#                 },
#                 {
#                     "source": "node1",
#                     "target": "node8"
#                 },
#                 {
#                     "source": "node2",
#                     "target": "node1"
#                 },
#                 {
#                     "source": "node2",
#                     "target": "node2"
#                 },
#                 {
#                     "source": "node2",
#                     "target": "node3"
#                 },
#                 {
#                     "source": "node2",
#                     "target": "node4"
#                 },
#                 {
#                     "source": "node2",
#                     "target": "node5"
#                 },
#                 {
#                     "source": "node2",
#                     "target": "node6"
#                 },
#                 {
#                     "source": "node2",
#                     "target": "node7"
#                 },
#                 {
#                     "source": "node2",
#                     "target": "node8"
#                 },
#                 {
#                     "source": "node3",
#                     "target": "node1"
#                 },
#                 {
#                     "source": "node3",
#                     "target": "node2"
#                 },
#                 {
#                     "source": "node3",
#                     "target": "node3"
#                 },
#                 {
#                     "source": "node3",
#                     "target": "node4"
#                 },
#                 {
#                     "source": "node3",
#                     "target": "node5"
#                 },
#                 {
#                     "source": "node3",
#                     "target": "node6"
#                 },
#                 {
#                     "source": "node3",
#                     "target": "node7"
#                 },
#                 {
#                     "source": "node3",
#                     "target": "node8"
#                 },
#                 {
#                     "source": "node4",
#                     "target": "node1"
#                 },
#                 {
#                     "source": "node4",
#                     "target": "node2"
#                 },
#                 {
#                     "source": "node4",
#                     "target": "node3"
#                 },
#                 {
#                     "source": "node4",
#                     "target": "node4"
#                 },
#                 {
#                     "source": "node4",
#                     "target": "node5"
#                 },
#                 {
#                     "source": "node4",
#                     "target": "node6"
#                 },
#                 {
#                     "source": "node4",
#                     "target": "node7"
#                 },
#                 {
#                     "source": "node4",
#                     "target": "node8"
#                 },
#                 {
#                     "source": "node5",
#                     "target": "node1"
#                 },
#                 {
#                     "source": "node5",
#                     "target": "node2"
#                 },
#                 {
#                     "source": "node5",
#                     "target": "node3"
#                 },
#                 {
#                     "source": "node5",
#                     "target": "node4"
#                 },
#                 {
#                     "source": "node5",
#                     "target": "node5"
#                 },
#                 {
#                     "source": "node5",
#                     "target": "node6"
#                 },
#                 {
#                     "source": "node5",
#                     "target": "node7"
#                 },
#                 {
#                     "source": "node5",
#                     "target": "node8"
#                 },
#                 {
#                     "source": "node6",
#                     "target": "node1"
#                 },
#                 {
#                     "source": "node6",
#                     "target": "node2"
#                 },
#                 {
#                     "source": "node6",
#                     "target": "node3"
#                 },
#                 {
#                     "source": "node6",
#                     "target": "node4"
#                 },
#                 {
#                     "source": "node6",
#                     "target": "node5"
#                 },
#                 {
#                     "source": "node6",
#                     "target": "node6"
#                 },
#                 {

# %% [markdown]
# # Graph Example - npm package dependencies

# %%
def graph_npm_dependencies() -> Graph:
    with open(os.path.join("fixtures", "npmdepgraph.json"), "r", encoding="utf-8") as f:
        j = json.load(f)
    nodes = [
        {
            "x": node["x"],
            "y": node["y"],
            "id": node["id"],
            "name": node["label"],
            "symbolSize": node["size"],
            "itemStyle": {"normal": {"color": node["color"]}},
        }
        for node in j["nodes"]
    ]

    edges = [
        {"source": edge["sourceID"], "target": edge["targetID"]} for edge in j["edges"]
    ]

    c = (
        Graph(init_opts=opts.InitOpts(width="1000px", height="600px"))
        .add(
            "",
            nodes=nodes,
            links=edges,
            layout="none",
            label_opts=opts.LabelOpts(is_show=False),
            linestyle_opts=opts.LineStyleOpts(width=0.5, curve=0.3, opacity=0.7),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Graph-NPM Dependencies"))
    )
    return c

graph_npm_dependencies().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d08a88b8f78a4f03b24663996a085f52" style="width:1000px; height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d08a88b8f78a4f03b24663996a085f52 = echarts.init(
#             document.getElementById('d08a88b8f78a4f03b24663996a085f52'), 'white', {renderer: 'canvas'});
#         var option_d08a88b8f78a4f03b24663996a085f52 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "none",
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 0.5,
#                 "opacity": 0.7,
#                 "curveness": 0.3,
#                 "type": "solid"
#             },
#             "roam": true,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "x": -739.36383,
#                     "y": -404.26147,
#                     "id": "jquery",
#                     "name": "jquery",
#                     "symbolSize": 4.7252817,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#4f19c7"
#                         }
#                     }
#                 },
#                 {
#                     "x": -134.2215,
#                     "y": -862.7517,
#                     "id": "backbone",
#                     "name": "backbone",
#                     "symbolSize": 6.1554675,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c71969"
#                         }
#                     }
#                 },
#                 {
#                     "x": -75.53079,
#                     "y": -734.4221,
#                     "id": "underscore",
#                     "name": "underscore",
#                     "symbolSize": 100.0,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c71969"
#                         }
#                     }
#                 },
#                 {
#                     "x": -818.97516,
#                     "y": 624.50604,
#                     "id": "faye",
#                     "name": "faye",
#                     "symbolSize": 0.67816025,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c71969"
#                         }
#                     }
#                 },
#                 {
#                     "x": -710.59204,
#                     "y": 120.37976,
#                     "id": "socket.io",
#                     "name": "socket.io",
#                     "symbolSize": 19.818306,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c71919"
#                         }
#                     }
#                 },
#                 {
#                     "x": 71.52897,
#                     "y": -612.5541,
#                     "id": "requirejs",
#                     "name": "requirejs",
#                     "symbolSize": 4.0862627,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c71969"
#                         }
#                     }
#                 },
#                 {
#                     "x": 1202.1166,
#                     "y": -556.3107,
#                     "id": "amdefine",
#                     "name": "amdefine",
#                     "symbolSize": 2.3822114,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c71969"
#                         }
#                     }
#                 },
#                 {
#                     "x": -1150.2018,
#                     "y": 378.15536,
#                     "id": "mongoose",
#                     "name": "mongoose",
#                     "symbolSize": 10.81118,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#1984c7"
#                         }
#                     }
#                 },
#                 {
#                     "x": -127.03764,
#                     "y": 477.03778,
#                     "id": "underscore.deferred",
#                     "name": "underscore.deferred",
#                     "symbolSize": 0.40429485,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c76919"
#                         }
#                     }
#                 },
#                 {
#                     "x": -338.03128,
#                     "y": -404.62427,
#                     "id": "cheerio",
#                     "name": "cheerio",
#                     "symbolSize": 8.163814,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#8419c7"
#                         }
#                     }
#                 },
#                 {
#                     "x": 118.30771,
#                     "y": -380.16626,
#                     "id": "lodash",
#                     "name": "lodash",
#                     "symbolSize": 18.935852,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c76919"
#                         }
#                     }
#                 },
#                 {
#                     "x": -697.4635,
#                     "y": 649.6795,
#                     "id": "faye-websocket",
#                     "name": "faye-websocket",
#                     "symbolSize": 1.0128845,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c71969"
#                         }
#                     }
#                 },
#                 {
#                     "x": 381.10724,
#                     "y": -531.28235,
#                     "id": "dateformat",
#                     "name": "dateformat",
#                     "symbolSize": 3.3863845,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c71969"
#                         }
#                     }
#                 },
#                 {
#                     "x": 317.77667,
#                     "y": -224.0287,
#                     "id": "mkdirp",
#                     "name": "mkdirp",
#                     "symbolSize": 23.713282,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c79f19"
#                         }
#                     }
#                 },
#                 {
#                     "x": -644.2716,
#                     "y": -230.14833,
#                     "id": "express",
#                     "name": "express",
#                     "symbolSize": 49.608772,
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#c71919"
#                         }
#                     }
#                 },
#                 {
#                     "x": -933.4234,
#                     "y": 294.88266,
#                     "id": "connect",
#                     "name": "connect",
#                     "symbolSize": 19.574871,
#                     "itemStyle": {
#                         "normal": {
#                             "colo

# %% [markdown]
# # Sankey

# %%
import json
import os

from example.commons import Collector
from pyecharts import options as opts
from pyecharts.charts import Page, Sankey


def sankey_base() -> Sankey:
    nodes = [
        {"name": "category1"},
        {"name": "category2"},
        {"name": "category3"},
        {"name": "category4"},
        {"name": "category5"},
        {"name": "category6"},
    ]

    links = [
        {"source": "category1", "target": "category2", "value": 10},
        {"source": "category2", "target": "category3", "value": 15},
        {"source": "category3", "target": "category4", "value": 20},
        {"source": "category5", "target": "category6", "value": 25},
    ]
    c = (
        Sankey()
        .add(
            "sankey",
            nodes,
            links,
            linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
            label_opts=opts.LabelOpts(position="right"),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Sankey basics"))
    )

    return c

sankey_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="13ce6ed367af4bbcaf80f075cf1d65bb" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_13ce6ed367af4bbcaf80f075cf1d65bb = echarts.init(
#             document.getElementById('13ce6ed367af4bbcaf80f075cf1d65bb'), 'white', {renderer: 'canvas'});
#         var option_13ce6ed367af4bbcaf80f075cf1d65bb = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "category1"
#                 },
#                 {
#                     "name": "category2"
#                 },
#                 {
#                     "name": "category3"
#                 },
#                 {
#                     "name": "category4"
#                 },
#                 {
#                     "name": "category5"
#                 },
#                 {
#                     "name": "category6"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "category1",
#                     "target": "category2",
#                     "value": 10
#                 },
#                 {
#                     "source": "category2",
#                     "target": "category3",
#                     "value": 15
#                 },
#                 {
#                     "source": "category3",
#                     "target": "category4",
#                     "value": 20
#                 },
#                 {
#                     "source": "category5",
#                     "target": "category6",
#                     "value": 25
#                 }
#             ],
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 0.2,
#                 "curveness": 0.5,
#                 "type": "solid",
#                 "color": "source"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sankey"
#             ],
#             "selected": {
#                 "sankey": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Sankey basics"
#         }
#     ]
# };
#         chart_13ce6ed367af4bbcaf80f075cf1d65bb.setOption(option_13ce6ed367af4bbcaf80f075cf1d65bb);
#     });
# </script>

# %% [markdown]
# # Sankey Example

# %%
def sankey_offical() -> Sankey:
    with open(os.path.join("fixtures", "energy.json"), "r", encoding="utf-8") as f:
        j = json.load(f)
    c = (
        Sankey()
        .add(
            "sankey",
            nodes=j["nodes"],
            links=j["links"],
            linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
            label_opts=opts.LabelOpts(position="right"),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Sankey - real world use case"))
    )
    return c


sankey_offical().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="56f906f4d9c145bba1422b899396376a" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_56f906f4d9c145bba1422b899396376a = echarts.init(
#             document.getElementById('56f906f4d9c145bba1422b899396376a'), 'white', {renderer: 'canvas'});
#         var option_56f906f4d9c145bba1422b899396376a = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "Agricultural 'waste'"
#                 },
#                 {
#                     "name": "Bio-conversion"
#                 },
#                 {
#                     "name": "Liquid"
#                 },
#                 {
#                     "name": "Losses"
#                 },
#                 {
#                     "name": "Solid"
#                 },
#                 {
#                     "name": "Gas"
#                 },
#                 {
#                     "name": "Biofuel imports"
#                 },
#                 {
#                     "name": "Biomass imports"
#                 },
#                 {
#                     "name": "Coal imports"
#                 },
#                 {
#                     "name": "Coal"
#                 },
#                 {
#                     "name": "Coal reserves"
#                 },
#                 {
#                     "name": "District heating"
#                 },
#                 {
#                     "name": "Industry"
#                 },
#                 {
#                     "name": "Heating and cooling - commercial"
#                 },
#                 {
#                     "name": "Heating and cooling - homes"
#                 },
#                 {
#                     "name": "Electricity grid"
#                 },
#                 {
#                     "name": "Over generation / exports"
#                 },
#                 {
#                     "name": "H2 conversion"
#                 },
#                 {
#                     "name": "Road transport"
#                 },
#                 {
#                     "name": "Agriculture"
#                 },
#                 {
#                     "name": "Rail transport"
#                 },
#                 {
#                     "name": "Lighting & appliances - commercial"
#                 },
#                 {
#                     "name": "Lighting & appliances - homes"
#                 },
#                 {
#                     "name": "Gas imports"
#                 },
#                 {
#                     "name": "Ngas"
#                 },
#                 {
#                     "name": "Gas reserves"
#                 },
#                 {
#                     "name": "Thermal generation"
#                 },
#                 {
#                     "name": "Geothermal"
#                 },
#                 {
#                     "name": "H2"
#                 },
#                 {
#                     "name": "Hydro"
#                 },
#                 {
#                     "name": "International shipping"
#                 },
#                 {
#                     "name": "Domestic aviation"
#                 },
#                 {
#                     "name": "International aviation"
#                 },
#                 {
#                     "name": "National navigation"
#                 },
#                 {
#                     "name": "Marine algae"
#                 },
#                 {
#                     "name": "Nuclear"
#                 },
#                 {
#                     "name": "Oil imports"
#                 },
#                 {
#                     "name": "Oil"
#                 },
#                 {
#                     "name": "Oil reserves"
#                 },
#                 {
#                     "name": "Other waste"
#                 },
#                 {
#                     "name": "Pumped heat"
#                 },
#                 {
#                     "name": "Solar PV"
#                 },
#                 {
#                     "name": "Solar Thermal"
#                 },
#                 {
#                     "name": "Solar"
#                 },
#                 {
#                     "name": "Tidal"
#                 },
#                 {
#                     "name": "UK land based bioenergy"
#                 },
#                 {
#                     "name": "Wave"
#                 },
#                 {
#                     "name": "Wind"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "Agricultural 'waste'",
#                     "target": "Bio-conversion",
#                     "value": 124.729
#                 },
#                 {
#                     "source": "Bio-conversion",
#                     "target": "Liquid",
#                     "value": 0.597
#                 },
#                 {
#                     "source": "Bio-conversion",
#                     "target": "Losses",
#                     "value": 26.862
#                 },
#                 {
#                     "source": "Bio-conversion",
#                     "target": "Solid",
#                     "value": 280.322
#                 },
#                 {
#                     "source": "Bio-conversion",
#                     "target": "Gas",
#                     "value": 81.144
#                 },
#                 {
#                     "source": "Biofuel imports",
#                     "target": "Liquid",
#                     "value": 35
#                 },
#                 {
#                     "source": "Biomass imports",
#                     "target": "Solid",
#                     "value": 35
#                 },
#                 {
#                     "source": "Coal imports",
#                     "target": "Coal",
#                     "value": 11.606
#                 },
#                 {
#                     "source": "Coal reserves",
#                     "target": "Coal",
#                     "value": 63.965
#                 },
#                 {
#                     "source": "Coal",
#                     "target": "Solid",
#                     "value": 75.571
#                 },
#                 {
#                     "source": "District heating",
#                     "target": "Industry",
#                     "value": 10.639
#                 },
#                 {
#                     "source": "District heating",
#                     "target": "Heating and cooling - commercial",
#                     "value": 22.505
#                 },
#                 {
#                     "source": "District heating",
#                     "target": "Heating and cooling - homes",
#                     "value": 46.184
#                 },
#                 {
#                     "source": "Electricity grid",
#                     "target": "Over generation / exports",
#                     "value": 104.453
#                 },
#                 {
#                     "source": "Electricity grid",
#                     "target": "Heating and cooling - homes",
#                     "value": 113.726
#                 },
#                 {
#                     "source": "Electricity grid",
#                     "target": "H2 conversion",
#                     "value": 27.14
#                 },
#                 {
#                     "source": "Electricity grid",
#                     "target": "Industry",
#                     "value": 342.165
#                 },
#                 {
#                     "source": "Electricity grid",
#                     "target": "Road transport",
